# %% [markdown]
# # WGU Capstone Project
# Blake Sutton - Student ID: 001109490
#
# ### Running the Necessary Imports

# %%
import pandas as pd
import numpy as np
import datetime

# %%
bike = pd.read_csv("BikeData.csv")

# %%
bike
# Out:
#             Date  Rented Bike Count  Hour  Temperature (C)  Humidity (%)  \
# 0     01/12/2017                254     0             -5.2            37
# 1     01/12/2017                204     1             -5.5            38
# 2     01/12/2017                173     2             -6.0            39
# 3     01/12/2017                107     3             -6.2            40
# 4     01/12/2017                 78     4             -6.0            36
# ...          ...                ...   ...              ...           ...
# 8755  30/11/2018               1003    19              4.2            34
# 8756  30/11/2018                764    20              3.4            37
# 8757  30/11/2018                694    21              2.6            39
# 8758  30/11/2018                712    22              2.1            41
# 8759  30/11/2018                584    23              1.9            43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature (C)  \
# 0                  2.2              2000                      -17.6
# 1                  0.8              2000                      -17.6
# 2                  1.0              2000                      -17.7
# 3                  0.9              2000                      -17.6
# 4                  2.3              2000                      -18.6
# ...                ...               ...                        ...
# 8755               2.6              1894                      -10.3
# 8756               2.3              2000                       -9.9
# 8757               0.3              1968                       -9.9
# 8758               1.0              1859                       -9.8
# 8759               1.3              1909                       -9.3
#
#       Solar Radiation (MJ/m2)  Rainfall (mm)  Snowfall (cm) Seasons  \
# 0                         0.0            0.0            0.0  Winter
# 1                         0.0            0.0            0.0  Winter
# 2                         0.0            0.0            0.0  Winter
# 3                         0.0            0.0            0.0  Winter
# 4                         0.0            0.0            0.0  Winter
# ...                       ...            ...            ...     ...
# 8755                      0.0            0.0            0.0  Autumn
# 8756                      0.0            0.0            0.0  Autumn
# 8757                      0.0            0.0            0.0  Autumn
# 8758                      0.0            0.0            0.0  Autumn
# 8759                      0.0            0.0            0.0  Autumn
#
#          Holiday Functioning Day
# 0     No Holiday             Yes
# 1     No Holiday             Yes
# 2     No Holiday             Yes
# 3     No Holiday             Yes
# 4     No Holiday             Yes
# ...          ...             ...
# 8755  No Holiday             Yes
# 8756  No Holiday             Yes
# 8757  No Holiday             Yes
# 8758  No Holiday             Yes
# 8759  No Holiday             Yes
#
# [8760 rows x 14 columns]

# %% [markdown]
# ### Creating a new "Datetime" column using the "Date" and "Hour" column data

# %%
# Reformatting the data in the "Date" column from dd/mm/yyyy to standard date format
for i in range(0, len(bike["Date"])):
    bike["Date"][i] = datetime.datetime.strptime(bike["Date"][i], "%d/%m/%Y").date()

# Creating pd dataframe with dictionary of Day: Hour
dt_df = pd.DataFrame({
    'Day': np.array(bike["Date"]), 
    'Hour': np.array(bike["Hour"])})

# Combining the "Date" and "Hour" data from each row into one cell in the "Datetime" column
bike["Datetime"] = pd.to_datetime(dt_df.Day) + pd.to_timedelta(dt_df.Hour, unit='h')
bike.head()
# Out:
# /var/folders/6n/r0mykfwn6tn5_cbb6h96dln00000gn/T/ipykernel_20756/2238263408.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bike["Date"][i] = datetime.datetime.strptime(bike["Date"][i], "%d/%m/%Y").date()
#          Date  Rented Bike Count  Hour  Temperature (C)  Humidity (%)  \
# 0  2017-12-01                254     0             -5.2            37
# 1  2017-12-01                204     1             -5.5            38
# 2  2017-12-01                173     2             -6.0            39
# 3  2017-12-01                107     3             -6.2            40
# 4  2017-12-01                 78     4             -6.0            36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature (C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall (mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0            0.0            0.0  Winter  No Holiday
# 1                      0.0            0.0            0.0  Winter  No Holiday
# 2                      0.0            0.0            0.0  Winter  No Holiday
# 3                      0.0            0.0            0.0  Winter  No Holiday
# 4                      0.0            0.0            0.0  Winter  No Holiday
#
#   Functioning Day            Datetime
# 0             Yes 2017-12-01 00:00:00
# 1             Yes 2017-12-01 01:00:00
# 2             Yes 2017-12-01 02:00:00
# 3             Yes 2017-12-01 03:00:00
# 4             Yes 2017-12-01 04:00:00

# %% [markdown]
# ### Number of Sales Over Time

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot');

# OO method from scratch
fig, ax = plt.subplots(figsize=(20,9));

## Plot the data
bar = ax.bar(bike["Datetime"],
             bike["Rented Bike Count"]);

# Customize the plot
ax.set(title='Sales Over Time',
       xlabel="Date",
       ylabel="Number of Sales");

# Add a legend
# ax.legend(*bar.legend_elements(), title="Target");

# Add a horizontal line
ax.axhline(bike["Rented Bike Count"].mean(),
            linestyle="--");

# %% [markdown]
# ### Relationship Between Bike Rentals and Temperature

# %%
plt.style.use('ggplot');

# Setting subplots
fig, ax = plt.subplots(figsize=(20,8))

# Plot the data
scatter = ax.scatter(x=bike["Temperature (C)"],
                     y=bike["Rented Bike Count"],
                     c=bike["Rented Bike Count"],
                     cmap='plasma');

# Customize the plot
ax.set(title='Relationship between Bike Rental and Temperature',
       xlabel="Temperature (C)",
       ylabel="Rented Bike Count");

# Add a legend
ax.legend(*scatter.legend_elements(), title="Rentals");

# Add a horizontal line
ax.axhline(bike["Rented Bike Count"].mean(),
           linestyle="--");

# %% [markdown]
# ### Relationship Between Bike Rentals and Rain

# %%
# Make copy of bike dataframe
bike["Precipitation"] = np.where((bike['Rainfall (mm)'] > 0) | (bike['Snowfall (cm)'] > 0), True, False)
bike
# Out:
#             Date  Rented Bike Count  Hour  Temperature (C)  Humidity (%)  \
# 0     2017-12-01                254     0             -5.2            37
# 1     2017-12-01                204     1             -5.5            38
# 2     2017-12-01                173     2             -6.0            39
# 3     2017-12-01                107     3             -6.2            40
# 4     2017-12-01                 78     4             -6.0            36
# ...          ...                ...   ...              ...           ...
# 8755  2018-11-30               1003    19              4.2            34
# 8756  2018-11-30                764    20              3.4            37
# 8757  2018-11-30                694    21              2.6            39
# 8758  2018-11-30                712    22              2.1            41
# 8759  2018-11-30                584    23              1.9            43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature (C)  \
# 0                  2.2              2000                      -17.6
# 1                  0.8              2000                      -17.6
# 2                  1.0              2000                      -17.7
# 3                  0.9              2000                      -17.6
# 4                  2.3              2000                      -18.6
# ...                ...               ...                        ...
# 8755               2.6              1894                      -10.3
# 8756               2.3              2000                       -9.9
# 8757               0.3              1968                       -9.9
# 8758               1.0              1859                       -9.8
# 8759               1.3              1909                       -9.3
#
#       Solar Radiation (MJ/m2)  Rainfall (mm)  Snowfall (cm) Seasons  \
# 0                         0.0            0.0            0.0  Winter
# 1                         0.0            0.0            0.0  Winter
# 2                         0.0            0.0            0.0  Winter
# 3                         0.0            0.0            0.0  Winter
# 4                         0.0            0.0            0.0  Winter
# ...                       ...            ...            ...     ...
# 8755                      0.0            0.0            0.0  Autumn
# 8756                      0.0            0.0            0.0  Autumn
# 8757                      0.0            0.0            0.0  Autumn
# 8758                      0.0            0.0            0.0  Autumn
# 8759                      0.0            0.0            0.0  Autumn
#
#          Holiday Functioning Day            Datetime  Precipitation
# 0     No Holiday             Yes 2017-12-01 00:00:00          False
# 1     No Holiday             Yes 2017-12-01 01:00:00          False
# 2     No Holiday             Yes 2017-12-01 02:00:00          False
# 3     No Holiday             Yes 2017-12-01 03:00:00          False
# 4     No Holiday             Yes 2017-12-01 04:00:00          False
# ...          ...             ...                 ...            ...
# 8755  No Holiday             Yes 2018-11-30 19:00:00          False
# 8756  No Holiday             Yes 2018-11-30 20:00:00          False
# 8757  No Holiday             Yes 2018-11-30 21:00:00          False
# 8758  No Holiday             Yes 2018-11-30 22:00:00          False
# 8759  No Holiday             Yes 2018-11-30 23:00:00          False
#
# [8760 rows x 16 columns]

# %%
plt.style.use('ggplot');

fig, ax = plt.subplots(figsize=(20,8))

## Plot the data
scatter = ax.scatter(x=bike["Datetime"],
                     y=bike["Rented Bike Count"],
                     c=bike["Precipitation"],
                     cmap='coolwarm_r');

# Customize the plot
ax.set(title='Relationship between Bike Rental and Temperature',
       xlabel="Date",
       ylabel="Rented Bike Count");

# Add a legend
ax.legend(*scatter.legend_elements(), title="Precipitation");

# Add a horizontal line
ax.axhline(bike["Rented Bike Count"].mean(),
           linestyle="--");

# %% [markdown]
# ### Relationship Between Bike Rentals and Humidity

# %%
plt.style.use('ggplot');

fig, ax = plt.subplots(figsize=(20,8))

## Plot the data
scatter = ax.scatter(x=bike["Humidity (%)"],
                     y=bike["Rented Bike Count"],
                     c=bike["Rented Bike Count"],
                     cmap="plasma");

# Customize the plot
ax.set(title='Relationship between Bike Rental and Humidity',
       xlabel="Humidity (%)",
       ylabel="Rented Bike Count");

# Add a legend
ax.legend(*scatter.legend_elements(), title="Rentals");

# Add a horizontal line
ax.axhline(bike["Rented Bike Count"].mean(),
           linestyle="--");

# %% [markdown]
# ### The First 25 Rows of the Data

# %%
bike.head(25)
# Out:
#           Date  Rented Bike Count  Hour  Temperature (C)  Humidity (%)  \
# 0   2017-12-01                254     0             -5.2            37
# 1   2017-12-01                204     1             -5.5            38
# 2   2017-12-01                173     2             -6.0            39
# 3   2017-12-01                107     3             -6.2            40
# 4   2017-12-01                 78     4             -6.0            36
# 5   2017-12-01                100     5             -6.4            37
# 6   2017-12-01                181     6             -6.6            35
# 7   2017-12-01                460     7             -7.4            38
# 8   2017-12-01                930     8             -7.6            37
# 9   2017-12-01                490     9             -6.5            27
# 10  2017-12-01                339    10             -3.5            24
# 11  2017-12-01                360    11             -0.5            21
# 12  2017-12-01                449    12              1.7            23
# 13  2017-12-01                451    13              2.4            25
# 14  2017-12-01                447    14              3.0            26
# 15  2017-12-01                463    15              2.1            36
# 16  2017-12-01                484    16              1.2            54
# 17  2017-12-01                555    17              0.8            58
# 18  2017-12-01                862    18              0.6            66
# 19  2017-12-01                600    19              0.0            77
# 20  2017-12-01                426    20             -0.3            79
# 21  2017-12-01                405    21             -0.8            81
# 22  2017-12-01                398    22             -0.9            83
# 23  2017-12-01                323    23             -1.3            84
# 24  2017-12-02                328     0             -1.8            87
#
#     Wind speed (m/s)  Visibility (10m)  Dew point temperature (C)  \
# 0                2.2              2000                      -17.6
# 1                0.8              2000                      -17.6
# 2                1.0              2000                      -17.7
# 3                0.9              2000                      -17.6
# 4                2.3              2000                      -18.6
# 5                1.5              2000                      -18.7
# 6                1.3              2000                      -19.5
# 7                0.9              2000                      -19.3
# 8                1.1              2000                      -19.8
# 9                0.5              1928                      -22.4
# 10               1.2              1996                      -21.2
# 11               1.3              1936                      -20.2
# 12               1.4              2000                      -17.2
# 13               1.6              2000                      -15.6
# 14               2.0              2000                      -14.6
# 15               3.2              2000                      -11.4
# 16               4.2               793                       -7.0
# 17               1.6              2000                       -6.5
# 18               1.4              2000                       -5.0
# 19               1.7              2000                       -3.5
# 20               1.5              1913                       -3.5
# 21               0.8              1687                       -3.6
# 22               1.5              1380                       -3.4
# 23               1.0              1265                       -3.6
# 24               1.1               994                       -3.6
#
#     Solar Radiation (MJ/m2)  Rainfall (mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.00            0.0            0.0  Winter  No Holiday
# 1                      0.00            0.0            0.0  Winter  No Holiday
# 2                      0.00            0.0            0.0  Winter  No Holiday
# 3                      0.00            0.0            0.0  Winter  No Holiday
# 4                      0.00            0.0            0.0  Winter  No Holiday
# 5                      0.00            0.0            0.0  Winter  No Holiday
# 6                      0.00            0.0            0.0  Winter  No Holiday
# 7                      0.00            0.0            0.0  Winter  No Holiday
# 8                      0.01            0.0            0.0  Winter  No Holiday
# 9                      0.23            0.0            0.0  Winter  No Holiday
# 10                     0.65            0.0            0.0  Winter  No Holiday
# 11                     0.94            0.0            0.0  Winter  No Holiday
# 12                     1.11            0.0            0.0  Winter  No Holiday
# 13                     1.16            0.0            0.0  Winter  No Holiday
# 14                     1.01            0.0            0.0  Winter  No Holiday
# 15                     0.54            0.0            0.0  Winter  No Holiday
# 16                     0.24            0.0            0.0  Winter  No Holiday
# 17                     0.08            0.0            0.0  Winter  No Holiday
# 18                     0.00            0.0            0.0  Winter  No Holiday
# 19                     0.00            0.0            0.0  Winter  No Holiday
# 20                     0.00            0.0            0.0  Winter  No Holiday
# 21                     0.00            0.0            0.0  Winter  No Holiday
# 22                     0.00            0.0            0.0  Winter  No Holiday
# 23                     0.00            0.0            0.0  Winter  No Holiday
# 24                     0.00            0.0            0.0  Winter  No Holiday
#
#    Functioning Day            Datetime  Precipitation
# 0              Yes 2017-12-01 00:00:00          False
# 1              Yes 2017-12-01 01:00:00          False
# 2              Yes 2017-12-01 02:00:00          False
# 3              Yes 2017-12-01 03:00:00          False
# 4              Yes 2017-12-01 04:00:00          False
# 5              Yes 2017-12-01 05:00:00          False
# 6              Yes 2017-12-01 06:00:00          False
# 7              Yes 2017-12-01 07:00:00          False
# 8              Yes 2017-12-01 08:00:00          False
# 9              Yes 2017-12-01 09:00:00          False
# 10             Yes 2017-12-01 10:00:00          False
# 11             Yes 2017-12-01 11:00:00          False
# 12             Yes 2017-12-01 12:00:00          False
# 13             Yes 2017-12-01 13:00:00          False
# 14             Yes 2017-12-01 14:00:00          False
# 15             Yes 2017-12-01 15:00:00          False
# 16             Yes 2017-12-01 16:00:00          False
# 17             Yes 2017-12-01 17:00:00          False
# 18             Yes 2017-12-01 18:00:00          False
# 19             Yes 2017-12-01 19:00:00          False
# 20             Yes 2017-12-01 20:00:00          False
# 21             Yes 2017-12-01 21:00:00          False
# 22             Yes 2017-12-01 22:00:00          False
# 23             Yes 2017-12-01 23:00:00          False
# 24             Yes 2017-12-02 00:00:00          False

# %% [markdown]
# ### Combining Sales, Temperature, Precipitation, and Humidity into One

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot');

# OO method from scratch
fig, (ax0, ax1, ax2) = plt.subplots(nrows=3,
                                    ncols=1,
                                    figsize=(20,30),
                                    sharex=True);

# ------ Sales Over Time ------
# Plot the data
sales_bar = ax0.bar(bike["Datetime"],
                    bike["Rented Bike Count"]);

# Customize the plot
ax0.set(title="Sales Over Time",
        xlabel="Date",
        ylabel="Number of Sales");

# Add a horizontal line
ax0.axhline(bike["Rented Bike Count"].mean(),
            linestyle="--");


# ------ Temperature Over Time -------
# Plot the data
temp_plot = ax1.plot(bike["Datetime"],
                     bike["Temperature (C)"]);

# Customize the plot
ax1.set(title="Temperature Over Time",
        xlabel="Datetime",
        ylabel="Temperature (C)");


# ------ Humidity Over Time ------
# Plot the data
hum_plot = ax2.plot(bike["Datetime"],
                    bike["Humidity (%)"]);

# Customize the plot
ax2.set(title="Humidity Over Time",
        xlabel="Datetime",
        ylabel="Humidity (%)");

fig.suptitle("Comparing Sales, Temperature, and Humidity", fontsize=16, fontweight='bold');
